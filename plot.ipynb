# %% [markdown]
# # Dependencies

# %%
import pickle
from toxic_data import *

# %% [markdown]
# # PCA reduction

# %%
from plot import plot_reduction
model_nickname = "llama3-8b"

plot_reduction(model_nickname,layers=30)

# %% [markdown]
# # Accuracy VS. Layers

# %%
from plot import plot_layer_accuracy
model_nickname = "mistral-7b"

plot_layer_accuracy(model_nickname)

# %% [markdown]
# # F1-score VS. Layers

# %%
from plot import plot_layer_f1
model_nickname = "llama3-8b"

plot_layer_f1(model_nickname)

# %% [markdown]
# # AUROC VS. Layers

# %%
from plot import plot_layer_auroc
model_nickname = "mistral-7b"

plot_layer_auroc(model_nickname)

# %% [markdown]
# # Similarity

# %%
from plot import plot_similarity
model_nickname = "llama3-8b"

plot_similarity(model_nickname,layers=[30])
